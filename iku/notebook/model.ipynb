# %%
import numpy as np
from numpy import array
from numpy import hstack
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow as tf
from tensorflow.keras import optimizers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Dropout

# %%
df = pd.read_csv("..\dataset\\psw.csv")

# %%
df
# Out:
#          aqi     co       datetime   no2    o3  pm10   pm25   so2
# 0       42.0   62.6  2023-12-31:16   5.0  26.7  15.3  10.00  12.0  \
# 1       42.0   61.3  2023-12-31:15   5.0  28.0  15.0  10.00  14.0
# 2       39.0   57.2  2023-12-31:14   4.7  30.7  14.3   9.33  13.0
# 3       36.0   53.1  2023-12-31:13   4.3  33.3  13.7   8.67  12.0
# 4       33.0   49.0  2023-12-31:12   4.0  36.0  13.0   8.00  11.0
# ...      ...    ...            ...   ...   ...   ...    ...   ...
# 17227  153.0  206.6  2022-01-12:21  30.0   7.0  78.0  55.00  47.0
# 17228  150.0  203.9  2022-01-12:20  30.7   7.7  78.7  55.67  53.0
# 17229  151.0  201.1  2022-01-12:19  31.3   8.3  79.3  56.33  59.0
# 17230  152.0  198.4  2022-01-12:18  32.0   9.0  80.0  57.00  65.0
# 17231  147.0  178.0  2022-01-12:17  27.7  13.7  74.0  52.67  57.0
#
#            timestamp_local        timestamp_utc          ts
# 0      2023-12-31T23:00:00  2023-12-31T16:00:00  1704038400
# 1      2023-12-31T22:00:00  2023-12-31T15:00:00  1704034800
# 2      2023-12-31T21:00:00  2023-12-31T14:00:00  1704031200
# 3      2023-12-31T20:00:00  2023-12-31T13:00:00  1704027600
# 4      2023-12-31T19:00:00  2023-12-31T12:00:00  1704024000
# ...                    ...                  ...         ...
# 17227  2022-01-13T04:00:00  2022-01-12T21:00:00  1642021200
# 17228  2022-01-13T03:00:00  2022-01-12T20:00:00  1642017600
# 17229  2022-01-13T02:00:00  2022-01-12T19:00:00  1642014000
# 17230  2022-01-13T01:00:00  2022-01-12T18:00:00  1642010400
# 17231  2022-01-13T00:00:00  2022-01-12T17:00:00  1642006800
#
# [17232 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17232 entries, 0 to 17231
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aqi              17158 non-null  float64
#  1   co               17158 non-null  float64
#  2   datetime         17232 non-null  object
#  3   no2              17158 non-null  float64
#  4   o3               17158 non-null  float64
#  5   pm10             17158 non-null  float64
#  6   pm25             17158 non-null  float64
#  7   so2              17158 non-null  float64
#  8   timestamp_local  17232 non-null  object
#  9   timestamp_utc    17232 non-null  object
#  10  ts               17232 non-null  int64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df = df.drop(["datetime",'timestamp_utc','ts',], axis=1)

# %%
df
# Out:
#          aqi     co   no2    o3  pm10   pm25   so2      timestamp_local
# 0       42.0   62.6   5.0  26.7  15.3  10.00  12.0  2023-12-31T23:00:00
# 1       42.0   61.3   5.0  28.0  15.0  10.00  14.0  2023-12-31T22:00:00
# 2       39.0   57.2   4.7  30.7  14.3   9.33  13.0  2023-12-31T21:00:00
# 3       36.0   53.1   4.3  33.3  13.7   8.67  12.0  2023-12-31T20:00:00
# 4       33.0   49.0   4.0  36.0  13.0   8.00  11.0  2023-12-31T19:00:00
# ...      ...    ...   ...   ...   ...    ...   ...                  ...
# 17227  153.0  206.6  30.0   7.0  78.0  55.00  47.0  2022-01-13T04:00:00
# 17228  150.0  203.9  30.7   7.7  78.7  55.67  53.0  2022-01-13T03:00:00
# 17229  151.0  201.1  31.3   8.3  79.3  56.33  59.0  2022-01-13T02:00:00
# 17230  152.0  198.4  32.0   9.0  80.0  57.00  65.0  2022-01-13T01:00:00
# 17231  147.0  178.0  27.7  13.7  74.0  52.67  57.0  2022-01-13T00:00:00
#
# [17232 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17232 entries, 0 to 17231
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aqi              17158 non-null  float64
#  1   co               17158 non-null  float64
#  2   no2              17158 non-null  float64
#  3   o3               17158 non-null  float64
#  4   pm10             17158 non-null  float64
#  5   pm25             17158 non-null  float64
#  6   so2              17158 non-null  float64
#  7   timestamp_local  17232 non-null  object
# dtypes: float64(7), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# # set index

# %%
# Konversi kolom timestamp_local ke tipe data timestamp_local
df['timestamp_local'] = pd.to_datetime(df['timestamp_local'])

# Pisahkan kolom timestamp_local menjadi jam, tanggal, bulan, dan tahun
df['jam'] = df['timestamp_local'].dt.hour
df['tanggal'] = df['timestamp_local'].dt.day
df['bulan'] = df['timestamp_local'].dt.month
df['tahun'] = df['timestamp_local'].dt.year

# %%
df.set_index('timestamp_local', inplace=True)

# %%
df
# Out:
#                        aqi     co   no2    o3  pm10   pm25   so2  jam
# timestamp_local
# 2023-12-31 23:00:00   42.0   62.6   5.0  26.7  15.3  10.00  12.0   23  \
# 2023-12-31 22:00:00   42.0   61.3   5.0  28.0  15.0  10.00  14.0   22
# 2023-12-31 21:00:00   39.0   57.2   4.7  30.7  14.3   9.33  13.0   21
# 2023-12-31 20:00:00   36.0   53.1   4.3  33.3  13.7   8.67  12.0   20
# 2023-12-31 19:00:00   33.0   49.0   4.0  36.0  13.0   8.00  11.0   19
# ...                    ...    ...   ...   ...   ...    ...   ...  ...
# 2022-01-13 04:00:00  153.0  206.6  30.0   7.0  78.0  55.00  47.0    4
# 2022-01-13 03:00:00  150.0  203.9  30.7   7.7  78.7  55.67  53.0    3
# 2022-01-13 02:00:00  151.0  201.1  31.3   8.3  79.3  56.33  59.0    2
# 2022-01-13 01:00:00  152.0  198.4  32.0   9.0  80.0  57.00  65.0    1
# 2022-01-13 00:00:00  147.0  178.0  27.7  13.7  74.0  52.67  57.0    0
#
#                      tanggal  bulan  tahun
# timestamp_local
# 2023-12-31 23:00:00       31     12   2023
# 2023-12-31 22:00:00       31     12   2023
# 2023-12-31 21:00:00       31     12   2023
# 2023-12-31 20:00:00       31     12   2023
# 2023-12-31 19:00:00       31     12   2023
# ...                      ...    ...    ...
# 2022-01-13 04:00:00       13      1   2022
# 2022-01-13 03:00:00       13      1   2022
# 2022-01-13 02:00:00       13      1   2022
# 2022-01-13 01:00:00       13      1   2022
# 2022-01-13 00:00:00       13      1   2022
#
# [17232 rows x 11 columns]

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='bulan', y='aqi', data=df)
plt.xlabel('Bulan')
plt.ylabel('AQI')
# Out:
# Text(0, 0.5, 'AQI')

# %%
sns.set_theme(style='whitegrid')
sns.set(rc={'figure.figsize': (15,8)})
ax = sns.boxplot(x='bulan', y="aqi", data=df)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='tanggal', y='aqi', data=df)
plt.xlabel('tanggal')
plt.ylabel('AQI')
# Out:
# Text(0, 0.5, 'AQI')

# %%
sns.set_theme(style='whitegrid')
sns.set(rc={'figure.figsize': (15,8)})
ax = sns.boxplot(x='tanggal', y="aqi", data=df)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='jam', y='aqi', data=df)
plt.xlabel('jam')
plt.ylabel('AQI')
# Out:
# Text(0, 0.5, 'AQI')

# %%
sns.set_theme(style='whitegrid')
sns.set(rc={'figure.figsize': (15,8)})
ax = sns.boxplot(x='jam', y="aqi", data=df)

# %% [markdown]
# # Correlation

# %%
# Correlation
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), cbar=True, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# # Handling missing value

# %%
df_input = df.drop(["jam",'tanggal','bulan','tahun'], axis=1)

# %%
df_input
# Out:
#                        aqi     co   no2    o3  pm10   pm25   so2
# timestamp_local
# 2023-12-31 23:00:00   42.0   62.6   5.0  26.7  15.3  10.00  12.0
# 2023-12-31 22:00:00   42.0   61.3   5.0  28.0  15.0  10.00  14.0
# 2023-12-31 21:00:00   39.0   57.2   4.7  30.7  14.3   9.33  13.0
# 2023-12-31 20:00:00   36.0   53.1   4.3  33.3  13.7   8.67  12.0
# 2023-12-31 19:00:00   33.0   49.0   4.0  36.0  13.0   8.00  11.0
# ...                    ...    ...   ...   ...   ...    ...   ...
# 2022-01-13 04:00:00  153.0  206.6  30.0   7.0  78.0  55.00  47.0
# 2022-01-13 03:00:00  150.0  203.9  30.7   7.7  78.7  55.67  53.0
# 2022-01-13 02:00:00  151.0  201.1  31.3   8.3  79.3  56.33  59.0
# 2022-01-13 01:00:00  152.0  198.4  32.0   9.0  80.0  57.00  65.0
# 2022-01-13 00:00:00  147.0  178.0  27.7  13.7  74.0  52.67  57.0
#
# [17232 rows x 7 columns]

# %%
sns.heatmap(df_input.isnull(), cbar=False, cmap='viridis')
# Out:
# <Axes: ylabel='timestamp_local'>

# %%
df_input.dropna(inplace=True)

# %%
print(df_input.isnull().sum())
print("shape: ", df_input.shape)
# Out:
# aqi     0
# co      0
# no2     0
# o3      0
# pm10    0
# pm25    0
# so2     0
# dtype: int64
# shape:  (17158, 7)

# %%
df_input.describe()
# Out:
#                 aqi            co           no2            o3          pm10
# count  17158.000000  17158.000000  17158.000000  17158.000000  17158.000000  \
# mean      76.591969    117.615829      7.818295     55.241654     35.578844
# std       33.776591     78.295147      7.328209     38.791121     21.678760
# min       17.000000     25.700000      0.000000      0.000000      1.000000
# 25%       54.000000     72.400000      2.300000     27.300000     20.300000
# 50%       69.000000    100.000000      5.700000     46.300000     30.700000
# 75%       93.000000    143.000000     10.700000     72.000000     44.700000
# max      271.000000   1463.400000     66.000000    300.000000    298.000000
#
#                pm25           so2
# count  17158.000000  17158.000000
# mean      24.366005     22.090628
# std       15.654591     30.352030
# min        0.000000      0.000000
# 25%       13.670000      1.000000
# 50%       20.670000      7.700000
# 75%       30.330000     33.000000
# max      209.000000    189.000000

# %% [markdown]
# # Preparation data

# %%
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        
        if out_end_ix > len(sequences):
            break
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix: out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
total_dataset =  len(df_input)
df_train = df_input[: int(total_dataset*0.87)]
df_test = df_input[int(total_dataset*0.87): total_dataset]

scaler = MinMaxScaler()
df_train_scaled = scaler.fit_transform(df_train)
df_test_scaled = scaler.fit_transform(df_test)

print("Data train: ", df_train.shape)
print("Total day for train: ", df_train.shape[0]/24)
print("Data test: ", df_test.shape)
print("Total day for test: ", df_test.shape[0]/24)
# Out:
# Data train:  (14927, 7)
# Total day for train:  621.9583333333334
# Data test:  (2231, 7)
# Total day for test:  92.95833333333333

# %%
n_steps_in, n_steps_out =  3, 1

x_train, y_train = split_sequences(df_train_scaled, n_steps_in, n_steps_out)
x_test, y_test = split_sequences(df_test_scaled, n_steps_in, n_steps_out)

n_features = x_train.shape[2]

# %%
print("Data input struktur untuk Training: ")
print(x_train[0])

print("Data output struktur untuk validasi: ")
print(y_train[0])
# Out:
# Data input struktur untuk Training:
# [[0.0984252  0.02566599 0.07575758 0.089      0.06965416 0.06060606
#   0.06349206]
#  [0.0984252  0.02476177 0.07575758 0.09333333 0.06819289 0.06060606
#   0.07407407]
#  [0.08661417 0.02191    0.07121212 0.10233333 0.06478324 0.05654545
#   0.06878307]]
# Data output struktur untuk validasi:
# [[0.07480315 0.01905822 0.06515152 0.111      0.06186069 0.05254545
#   0.06349206]]

# %%
print("Total Fitur: ", n_features)
print("Total Train data: ", x_train.shape)
print("Total Validation Train data: ", y_train.shape)
print("Total Test data: ", x_test.shape)
print("Total Validation Test data: ", y_test.shape)
# Out:
# Total Fitur:  7
# Total Train data:  (14924, 3, 7)
# Total Validation Train data:  (14924, 1, 7)
# Total Test data:  (2228, 3, 7)
# Total Validation Test data:  (2228, 1, 7)

# %% [markdown]
# # Modelling

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(200, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 200)               166400
#
#  repeat_vector_4 (RepeatVec  (None, 1, 200)            0
#  tor)
#
#  lstm_9 (LSTM)               (None, 1, 200)            320800
#
#  time_distributed_4 (TimeDi  (None, 1, 7)              1407
#  stributed)
#
# =================================================================
# Total params: 488607 (1.86 MB)
# Trainable params: 488607 (1.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit model
epoch = 20

model.compile(optimizer='adam', loss='mse', 
              metrics=[tf.metrics.MeanAbsoluteError()])

history = model.fit(x_train, y_train, epochs=epoch, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 467/467 [==============================] - 10s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0341 - val_loss: 0.0040 - val_mean_absolute_error: 0.0454
# Epoch 2/20
# 467/467 [==============================] - 7s 14ms/step - loss: 8.5262e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0024 - val_mean_absolute_error: 0.0344
# Epoch 3/20
# 467/467 [==============================] - 7s 15ms/step - loss: 6.5749e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0021 - val_mean_absolute_error: 0.0322
# Epoch 4/20
# 467/467 [==============================] - 7s 14ms/step - loss: 5.7992e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0018 - val_mean_absolute_error: 0.0297
# Epoch 5/20
# 467/467 [==============================] - 6s 14ms/step - loss: 5.4701e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 6/20
# 467/467 [==============================] - 6s 14ms/step - loss: 5.1268e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0016 - val_mean_absolute_error: 0.0265
# Epoch 7/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.9100e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0013 - val_mean_absolute_error: 0.0248
# Epoch 8/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.8313e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0017 - val_mean_absolute_error: 0.0280
# Epoch 9/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.7174e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 10/20
# 467/467 [==============================] - 6s 13ms/step - loss: 4.6190e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0014 - val_mean_absolute_error: 0.0255
# Epoch 11/20
# 467/467 [==============================] - 6s 13ms/step - loss: 4.5614e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0015 - val_mean_absolute_error: 0.0269
# Epoch 12/20
# 467/467 [==============================] - 7s 14ms/step - loss: 4.4630e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0015 - val_mean_absolute_error: 0.0269
# Epoch 13/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.4046e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0017 - val_mean_absolute_error: 0.0284
# Epoch 14/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.4074e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0014 - val_mean_absolute_error: 0.0257
# Epoch 15/20
# 467/467 [==============================] - 6s 13ms/step - loss: 4.3857e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 16/20
# 467/467 [==============================] - 6s 13ms/step - loss: 4.3242e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0013 - val_mean_absolute_error: 0.0244
# Epoch 17/20
# 467/467 [==============================] - 6s 13ms/step - loss: 4.2058e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0013 - val_mean_absolute_error: 0.0247
# Epoch 18/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.2299e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0015 - val_mean_absolute_error: 0.0264
# Epoch 19/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.0843e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0011 - val_mean_absolute_error: 0.0219
# Epoch 20/20
# 467/467 [==============================] - 6s 14ms/step - loss: 4.2166e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0012 - val_mean_absolute_error: 0.0246

# %% [markdown]
# # Test Model

# %%
predictions = model.predict_generator(x_test)
print(predictions.shape)
print(y_test.shape)
# Out:
# C:\Users\62877\AppData\Local\Temp\ipykernel_11640\1237770610.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(x_test)
# (2228, 1, 7)
# (2228, 1, 7)

# %%
predictions = np.reshape(predictions, (2228*1, 7))
real = np.reshape(y_test, (2228*1, 7))

predictions = pd.DataFrame(predictions)
predictions = scaler.inverse_transform(predictions)
predictions = pd.DataFrame(predictions)

real = pd.DataFrame(real)
real = scaler.inverse_transform(real)
real = pd.DataFrame(real)

print(predictions.shape)
print(real.shape)
# Out:
# (2228, 7)
# (2228, 7)

# %%
predictions
# Out:
#                0           1          2           3           4          5
# 0     118.925949  126.937721  11.048027   64.758545   71.296501  42.721928  \
# 1     107.530037  110.844322   6.765363   76.252388   58.379398  35.438747
# 2     114.192566  116.509201   5.580224   95.959953   54.451515  33.529381
# 3     115.100235  116.412415   3.773475  107.613724   48.165699  30.777235
# 4     119.516533  116.532692   2.254586  120.135788   43.456947  28.380424
# ...          ...         ...        ...         ...         ...        ...
# 2223  140.444351  199.144119  27.880547    8.644808   98.914764  64.307419
# 2224  141.200089  203.998703  30.137466    4.926658  100.404800  65.305237
# 2225  139.498642  193.269394  29.485220    6.982906   98.798492  64.138420
# 2226  141.273727  188.148865  29.504461    7.534480  100.996475  65.448250
# 2227  142.113785  182.617935  29.342710    8.115477  102.360931  66.276360
#
#               6
# 0     32.858562
# 1     23.722815
# 2     22.195091
# 3     16.248701
# 4     12.223559
# ...         ...
# 2223  45.257603
# 2224  51.926929
# 2225  56.969929
# 2226  63.012474
# 2227  68.308128
#
# [2228 rows x 7 columns]

# %%
real
# Out:
#           0      1     2      3     4      5     6
# 0     115.0  122.0  11.0   66.0  57.0  41.00  28.0
# 1     104.0  111.9   8.0   83.7  51.7  37.00  22.0
# 2      95.0  101.7   5.0  101.3  46.3  33.00  16.0
# 3      87.0   91.6   2.0  119.0  41.0  29.00  10.0
# 4      87.0   91.8   1.7  120.7  41.7  29.33   9.7
# ...     ...    ...   ...    ...   ...    ...   ...
# 2223  153.0  206.6  30.0    7.0  78.0  55.00  47.0
# 2224  150.0  203.9  30.7    7.7  78.7  55.67  53.0
# 2225  151.0  201.1  31.3    8.3  79.3  56.33  59.0
# 2226  152.0  198.4  32.0    9.0  80.0  57.00  65.0
# 2227  147.0  178.0  27.7   13.7  74.0  52.67  57.0
#
# [2228 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17232 entries, 2023-12-31 23:00:00 to 2022-01-13 00:00:00
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   aqi      17158 non-null  float64
#  1   co       17158 non-null  float64
#  2   no2      17158 non-null  float64
#  3   o3       17158 non-null  float64
#  4   pm10     17158 non-null  float64
#  5   pm25     17158 non-null  float64
#  6   so2      17158 non-null  float64
#  7   jam      17232 non-null  int32
#  8   tanggal  17232 non-null  int32
#  9   bulan    17232 non-null  int32
#  10  tahun    17232 non-null  int32
# dtypes: float64(7), int32(4)
# memory usage: 1.3 MB

# %%
df_final = pd.DataFrame()

# %%
df_final['aqi'] = real[0]
df_final['co'] = real[1]
df_final['no2'] = real[2]
df_final['o3'] = real[3]
df_final['pm10'] = real[4]
df_final['pm25'] = real[5]
df_final['so2'] = real[6]

df_final['aqi_pred'] = predictions[0]
df_final['co_pred'] = predictions[1]
df_final['no2_pred'] = predictions[2]
df_final['o3_pred'] = predictions[3]
df_final['pm10_pred'] = predictions[4]
df_final['pm25_pred'] = predictions[5]
df_final['so2_pred'] = predictions[6]

# %%
df_final
# Out:
#         aqi     co   no2     o3  pm10   pm25   so2    aqi_pred     co_pred
# 0     115.0  122.0  11.0   66.0  57.0  41.00  28.0  118.925949  126.937721  \
# 1     104.0  111.9   8.0   83.7  51.7  37.00  22.0  107.530037  110.844322
# 2      95.0  101.7   5.0  101.3  46.3  33.00  16.0  114.192566  116.509201
# 3      87.0   91.6   2.0  119.0  41.0  29.00  10.0  115.100235  116.412415
# 4      87.0   91.8   1.7  120.7  41.7  29.33   9.7  119.516533  116.532692
# ...     ...    ...   ...    ...   ...    ...   ...         ...         ...
# 2223  153.0  206.6  30.0    7.0  78.0  55.00  47.0  140.444351  199.144119
# 2224  150.0  203.9  30.7    7.7  78.7  55.67  53.0  141.200089  203.998703
# 2225  151.0  201.1  31.3    8.3  79.3  56.33  59.0  139.498642  193.269394
# 2226  152.0  198.4  32.0    9.0  80.0  57.00  65.0  141.273727  188.148865
# 2227  147.0  178.0  27.7   13.7  74.0  52.67  57.0  142.113785  182.617935
#
#        no2_pred     o3_pred   pm10_pred  pm25_pred   so2_pred
# 0     11.048027   64.758545   71.296501  42.721928  32.858562
# 1      6.765363   76.252388   58.379398  35.438747  23.722815
# 2      5.580224   95.959953   54.451515  33.529381  22.195091
# 3      3.773475  107.613724   48.165699  30.777235  16.248701
# 4      2.254586  120.135788   43.456947  28.380424  12.223559
# ...         ...         ...         ...        ...        ...
# 2223  27.880547    8.644808   98.914764  64.307419  45.257603
# 2224  30.137466    4.926658  100.404800  65.305237  51.926929
# 2225  29.485220    6.982906   98.798492  64.138420  56.969929
# 2226  29.504461    7.534480  100.996475  65.448250  63.012474
# 2227  29.342710    8.115477  102.360931  66.276360  68.308128
#
# [2228 rows x 14 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# Menghitung metrik evaluasi untuk LSTM
mse_lstm = mean_squared_error(real[1], predictions[1])
r2_lstm = r2_score(real[1], predictions[1])
mae_lstm = mean_absolute_error(real[1], predictions[1])
rmse_lstm = np.sqrt(mse_lstm)

# Menampilkan hasil evaluasi untuk LSTM
print("LSTM:")
print("Mean Squared Error (MSE):", mse_lstm)
print("R-squared (R2):", r2_lstm)
print("Mean Absolute Error (MAE):", mae_lstm)
print("Root Mean Squared Error (RMSE):", rmse_lstm)
# Out:
# LSTM:
# Mean Squared Error (MSE): 221.70377106398243
# R-squared (R2): 0.9603314189082806
# Mean Absolute Error (MAE): 8.83801671923598
# Root Mean Squared Error (RMSE): 14.889720315169873

# %%
mpl.rcParams['figure.figsize'] = (8,4)
mpl.rcParams['axes.grid'] = False
df_final[['aqi', 'aqi_pred']].plot()
df_final[['co', 'co_pred']].plot()
df_final[['no2', 'no2_pred']].plot()
df_final[['o3', 'o3_pred']].plot()
df_final[['pm10', 'pm10_pred']].plot()
df_final[['pm25', 'pm25_pred']].plot()
df_final[['so2', 'so2_pred']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Save Model

# %%
model.save("../model/psw.h5")
# Out:
# c:\Users\62877\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pkg_resources

# Pandas version
pandas_version = pkg_resources.get_distribution("pandas").version
print("Pandas version:", pandas_version)

# NumPy version
numpy_version = pkg_resources.get_distribution("numpy").version
print("NumPy version:", numpy_version)

# Requests version
requests_version = pkg_resources.get_distribution("requests").version
print("Requests version:", requests_version)

# Glom version
glom_version = pkg_resources.get_distribution("glom").version
print("Glom version:", glom_version)
# Out:
# Pandas version: 2.0.1
# NumPy version: 1.23.5
# Requests version: 2.31.0
# Glom version: 23.5.0

# %%
import pkg_resources

# Streamlit version
streamlit_version = pkg_resources.get_distribution("streamlit").version
print("Streamlit version:", streamlit_version)
# Out:
# Streamlit version: 1.33.0
